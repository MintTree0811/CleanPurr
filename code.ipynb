# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Main.csv')
# Out:
# C:\Users\Acer\AppData\Roaming\Python\Python36\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (8,9,10,11,12,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Data Preparation

# %%
df.dropna(subset=['Total Sales'],inplace=True)
df.drop(['Total Shipped'],axis =1 ,inplace=True)

# %%
df.reset_index(inplace=True)
df
# Out:
#        index  Position                              Game Name Console  \
# 0        160       161                 Grand Theft Auto V         PS3
# 1        186       187                 Grand Theft Auto V         PS4
# 2        219       220        Grand Theft Auto: Vice City         PS2
# 3        225       226                 Grand Theft Auto V        X360
# 4        231       232          Call of Duty: Black Ops 3         PS4
# ...      ...       ...                                    ...     ...
# 18866  23014     23165       Mind, Body & Soul: Blend It!          DS
# 18867  23015     23166              Ride! Carnival Tycoon          PC
# 18868  23016     23167      Shinobido: Tales of the Ninja         PSP
# 18869  23017     23168    Tactical Ops: Assault on Terror          PC
# 18870  23018     23169  World in Conflict: Soviet Assault          PC
#
#                            Publisher  \
# 0                   Rockstar Games
# 1                   Rockstar Games
# ...

# %%
df.drop(['index','Position'],axis =1 ,inplace=True)

# %%
df
# Out:
#                                    Game Name Console  \
# 0                     Grand Theft Auto V         PS3
# 1                     Grand Theft Auto V         PS4
# 2            Grand Theft Auto: Vice City         PS2
# 3                     Grand Theft Auto V        X360
# 4              Call of Duty: Black Ops 3         PS4
# ...                                      ...     ...
# 18866       Mind, Body & Soul: Blend It!          DS
# 18867              Ride! Carnival Tycoon          PC
# 18868      Shinobido: Tales of the Ninja         PSP
# 18869    Tactical Ops: Assault on Terror          PC
# 18870  World in Conflict: Soviet Assault          PC
#
#                            Publisher  \
# 0                   Rockstar Games
# 1                   Rockstar Games
# 2                   Rockstar Games
# 3                   Rockstar Games
# 4                       Activision
# ...                              ...
# 18866                    505 Games
# ...

# %%
dfm = df[['Game Name','Console','Publisher','Developer','Last Update','NA Sales','PAL Sales','Japan Sales','Other Sales']]

# %%
output = (dfm.set_index(['Game Name','Console','Publisher','Developer','Last Update'])
   .stack(dropna=False)
   .reset_index()
   .rename({'level_5': 'Region', '0':'Sales'}, axis=1))

# %%
output
# Out:
#                                    Game Name Console         Publisher  \
# 0                     Grand Theft Auto V         PS3  Rockstar Games
# 1                     Grand Theft Auto V         PS3  Rockstar Games
# 2                     Grand Theft Auto V         PS3  Rockstar Games
# 3                     Grand Theft Auto V         PS3  Rockstar Games
# 4                     Grand Theft Auto V         PS4  Rockstar Games
# ...                                      ...     ...               ...
# 75479    Tactical Ops: Assault on Terror          PC           Atari
# 75480  World in Conflict: Soviet Assault          PC         Ubisoft
# 75481  World in Conflict: Soviet Assault          PC         Ubisoft
# 75482  World in Conflict: Soviet Assault          PC         Ubisoft
# 75483  World in Conflict: Soviet Assault          PC         Ubisoft
#
#                                          Developer  Last Update       Region  \
# ...

# %%
dfm.stack(dropna=False).reset_index()
# Out:
#                                    Game Name      level_1      0
# 0                     Grand Theft Auto V         NA Sales  6.37m
# 1                     Grand Theft Auto V        PAL Sales  9.85m
# 2                     Grand Theft Auto V      Japan Sales  0.99m
# 3                     Grand Theft Auto V      Other Sales  3.12m
# 4                     Grand Theft Auto V         NA Sales  6.06m
# ...                                      ...          ...    ...
# 75479    Tactical Ops: Assault on Terror      Other Sales    NaN
# 75480  World in Conflict: Soviet Assault         NA Sales    NaN
# 75481  World in Conflict: Soviet Assault        PAL Sales  0.00m
# 75482  World in Conflict: Soviet Assault      Japan Sales    NaN
# 75483  World in Conflict: Soviet Assault      Other Sales    NaN
#
# [75484 rows x 3 columns]

# %% [markdown]
# ## OUTPUT

# %%
output.to_csv('New.csv')

# %%
df.to_csv('Out.csv')
